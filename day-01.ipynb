# %%
import pandas as pd
import numpy as np

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite://')
student_productivity.to_sql('my_table', engine, index=False)
student_productivity1.to_sql('my_table1', engine, index=False)
# Out:
# 20000

# %%
student_productivity = pd.read_csv(r"C:\Users\sukai\Downloads\archive (2).zip")
student_productivity.head()
# Out:
#    student_id  age gender academic_level  study_hours  self_study_hours  \
# 0           1   18  Other    High School         7.64              1.56
# 1           2   18  Other    High School         2.21              2.22
# 2           3   22   Male    High School         3.45              0.00
# 3           4   17  Other    High School         5.75              2.08
# 4           5   19  Other    High School         6.83              1.72
#
#    online_classes_hours  social_media_hours  gaming_hours  sleep_hours  ...  \
# 0                  2.20                3.05          2.19         6.52  ...
# 1                  2.10                1.65          2.55         5.97  ...
# 2                  0.29                1.34          2.08         8.39  ...
# 3                  3.01                2.27          2.20         6.31  ...
# 4                  3.33                2.65          0.70         8.01  ...
#
# ...

# %%
student_productivity.shape
# Out:
# (5000, 21)

# %%
print("MEAN : ", np.mean(student_productivity.study_hours))
print("MEDIAN : ", np.median(student_productivity.study_hours))
print("STANDARD DEVIATION : ", np.std(student_productivity.study_hours))
# Out:
# MEAN :  4.539594
# MEDIAN :  4.53
# STANDARD DEVIATION :  1.8214827078959608

# %%
household_details = pd.DataFrame({"Adults":[3, 6], "Kids":[3, 1]}, index = (["Under 80", "Under 60"]))
print(household_details)
# Out:
#           Adults  Kids
# Under 80       3     3
# Under 60       6     1

# %%
Grocery_list = pd.Series([6, 1, 4, 2], index = (["Eggs", "Milk", "Biscuits", "Chapati Packet"]), name = "Grocery List")
print(Grocery_list)
# Out:
# Eggs              6
# Milk              1
# Biscuits          4
# Chapati Packet    2
# Name: Grocery List, dtype: int64

# %%
query = """
SELECT * FROM my_table;
"""
sql_my_table = pd.read_sql_query(query, con=engine)
print(sql_my_table.head())
# Out:
#    student_id  age gender academic_level  study_hours  self_study_hours  \
# 0           1   18  Other    High School         7.64              1.56
# 1           2   18  Other    High School         2.21              2.22
# 2           3   22   Male    High School         3.45              0.00
# 3           4   17  Other    High School         5.75              2.08
# 4           5   19  Other    High School         6.83              1.72
#
#    online_classes_hours  social_media_hours  gaming_hours  sleep_hours  ...  \
# 0                  2.20                3.05          2.19         6.52  ...
# 1                  2.10                1.65          2.55         5.97  ...
# 2                  0.29                1.34          2.08         8.39  ...
# 3                  3.01                2.27          2.20         6.31  ...
# 4                  3.33                2.65          0.70         8.01  ...
#
# ...

# %%
query = """
SELECT age FROM my_table WHERE age > 18;
"""
sql_my_table = pd.read_sql_query(query, con=engine)
print(sql_my_table)
# Out:
#       age
# 0      22
# 1      19
# 2      25
# 3      22
# 4      25
# ...   ...
# 3508   21
# 3509   20
# 3510   24
# 3511   22
# 3512   22
#
# [3513 rows x 1 columns]

# %%
query = """
SELECT study_hours, sleep_hours FROM my_table;
"""
sql_my_table = pd.read_sql_query(query, con=engine)
print(sql_my_table.head())
# Out:
#    study_hours  sleep_hours
# 0         7.64         6.52
# 1         2.21         5.97
# 2         3.45         8.39
# 3         5.75         6.31
# 4         6.83         8.01

# %%
query = """
SELECT focus_index FROM my_table WHERE focus_index BETWEEN 10 AND 30;
"""
sql_my_table = pd.read_sql_query(query, con=engine)
print(sql_my_table.head())
# Out:
#    focus_index
# 0        15.92
# 1        27.39
# 2        22.31
# 3        20.26
# 4        19.21

# %%
query = """
SELECT burnout_level FROM my_table where burnout_level NOT BETWEEN 30 AND 40;
"""
sql_my_table = pd.read_sql_query(query, con=engine)
print(sql_my_table.head())
# Out:
#    burnout_level
# 0          77.31
# 1          62.01
# 2          45.98
# 3          49.44
# 4          60.78

# %%
query = """
SELECT social_media_hours FROM my_table WHERE social_media_hours IN(2.27);
"""
sql_my_table = pd.read_sql_query(query, con=engine)
print(sql_my_table.head())
# Out:
#    social_media_hours
# 0                2.27
# 1                2.27
# 2                2.27
# 3                2.27
# 4                2.27

# %%
query = """
SELECT social_media_hours FROM my_table WHERE social_media_hours NOT IN(3.05);
"""
sql_my_table = pd.read_sql_query(query, con=engine)
print(sql_my_table.head())
# Out:
#    social_media_hours
# 0                1.65
# 1                1.34
# 2                2.27
# 3                2.65
# 4                4.47

# %%
query = """
SELECT mental_health_score FROM my_table WHERE mental_health_score>3 AND mental_health_score<10;
"""
sql_my_table = pd.read_sql_query(query, con=engine)
print(sql_my_table.head())
# Out:
#    mental_health_score
# 0                    8
# 1                    8
# 2                    8
# 3                    6
# 4                    9

# %%
query = """
SELECT student_id FROM my_table WHERE self_study_hours>2 OR exam_score>30;
"""
sql_my_table = pd.read_sql_query(query, con=engine)
print(sql_my_table.head())
# Out:
#    student_id
# 0           1
# 1           2
# 2           4
# 3           6
# 4           7

# %%
student_productivity1 = pd.read_csv(r"C:\Users\sukai\Downloads\archive (3).zip")
student_productivity1.head()
# Out:
#    student_id  age  gender  study_hours_per_day  sleep_hours  \
# 0           1   23  Female                 4.35         3.63
# 1           2   20    Male                 6.14         6.58
# 2           3   29  Female                 4.98         3.26
# 3           4   27  Female                 3.19         4.58
# 4           5   24    Male                 7.67         6.21
#
#    phone_usage_hours  social_media_hours  youtube_hours  gaming_hours  \
# 0               3.38                2.73           1.83          5.26
# 1               5.48                1.51           3.13          1.73
# 2               4.83                3.63           0.18          4.71
# 3              10.06                3.95           5.75          2.52
# 4               3.02                1.59           5.46          5.65
#
#    breaks_per_day  coffee_intake_mg  exercise_minutes  assignments_completed  \
# 0               6               347               111                      2
# ...

# %%
query = """
SELECT * FROM my_table1;
"""
sql_my_table = pd.read_sql_query(query, con=engine)
print(sql_my_table.head())
# Out:
#    student_id  age  gender  study_hours_per_day  sleep_hours  \
# 0           1   23  Female                 4.35         3.63
# 1           2   20    Male                 6.14         6.58
# 2           3   29  Female                 4.98         3.26
# 3           4   27  Female                 3.19         4.58
# 4           5   24    Male                 7.67         6.21
#
#    phone_usage_hours  social_media_hours  youtube_hours  gaming_hours  \
# 0               3.38                2.73           1.83          5.26
# 1               5.48                1.51           3.13          1.73
# 2               4.83                3.63           0.18          4.71
# 3              10.06                3.95           5.75          2.52
# 4               3.02                1.59           5.46          5.65
#
#    breaks_per_day  coffee_intake_mg  exercise_minutes  assignments_completed  \
# 0               6               347               111                      2
# ...

# %%
query = """
SELECT student_id FROM my_table1 WHERE gender != "Male";
"""
sql_my_table = pd.read_sql_query(query, con=engine)
print(sql_my_table.head())
# Out:
#    student_id
# 0           1
# 1           3
# 2           4
# 3           6
# 4           7

# %%
query = """
SELECT student_id FROM my_table1 WHERE gender LIKE "Male";
"""
sql_my_table = pd.read_sql_query(query, con=engine)
print(sql_my_table.head())
# Out:
#    student_id
# 0           2
# 1           5
# 2           9
# 3          11
# 4          12

# %%
query = """
SELECT student_id FROM my_table1 WHERE gender NOT LIKE "Male";
"""
sql_my_table = pd.read_sql_query(query, con=engine)
print(sql_my_table.head())
# Out:
#    student_id
# 0           1
# 1           3
# 2           4
# 3           6
# 4           7

# %%
query = """
SELECT sleep_hours FROM my_table1 WHERE gender LIKE "Female";
"""
sql_my_table = pd.read_sql_query(query, con=engine)
print(sql_my_table.head())
# Out:
#    sleep_hours
# 0         3.63
# 1         3.26
# 2         4.58
# 3         6.36
# 4         4.86

# %%
query = """
SELECT gaming_hours FROM my_table1 WHERE gender LIKE "Male";
"""
sql_my_table = pd.read_sql_query(query, con=engine)
print(sql_my_table.head())
# Out:
#    gaming_hours
# 0          1.73
# 1          5.65
# 2          3.38
# 3          1.36
# 4          0.20

# %%
query = """
SELECT age FROM my_table1 WHERE gender LIKE "Fe%ale";
"""
sql_my_table = pd.read_sql_query(query, con=engine)
print(sql_my_table.head())
# Out:
#    age
# 0   23
# 1   29
# 2   27
# 3   21
# 4   23

# %%
query = """
SELECT phone_usage_hours FROM my_table1 WHERE gender LIKE "mal_";
"""
sql_my_table = pd.read_sql_query(query, con=engine)
print(sql_my_table.head())
# Out:
#    phone_usage_hours
# 0               5.48
# 1               3.02
# 2               9.66
# 3               7.25
# 4               1.56
