# %%
import pandas as pd

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite://')
student_productivity.to_sql('my_table', engine, index=False)
# Out:
# 20000

# %%
student_productivity = pd.read_csv(r"C:\Users\sukai\Downloads\archive (3).zip")
student_productivity.head()
student_productivity.shape
# Out:
# (20000, 18)

# %%
student_productivity.study_hours_per_day
# Out:
# 0        4.35
# 1        6.14
# 2        4.98
# 3        3.19
# 4        7.67
#          ...
# 19995    4.81
# 19996    0.83
# 19997    9.36
# 19998    0.74
# 19999    3.64
# Name: study_hours_per_day, Length: 20000, dtype: float64

# %%
student_productivity["study_hours_per_day"]
# Out:
# 0        4.35
# 1        6.14
# 2        4.98
# 3        3.19
# 4        7.67
#          ...
# 19995    4.81
# 19996    0.83
# 19997    9.36
# 19998    0.74
# 19999    3.64
# Name: study_hours_per_day, Length: 20000, dtype: float64

# %%
student_productivity.age[10]
# Out:
# np.int64(23)

# %%
student_productivity["exercise_minutes"][100]
# Out:
# np.int64(46)

# %%
student_productivity.breaks_per_day.iloc[:]
# Out:
# 0         6
# 1        13
# 2         1
# 3         9
# 4         8
#          ..
# 19995     6
# 19996     1
# 19997     4
# 19998     7
# 19999     8
# Name: breaks_per_day, Length: 20000, dtype: int64

# %%
student_productivity.assignments_completed.iloc[1000]
# Out:
# np.int64(10)

# %%
student_productivity.iloc[1:6, 6]
# Out:
# 1    1.51
# 2    3.63
# 3    3.95
# 4    1.59
# 5    3.74
# Name: social_media_hours, dtype: float64

# %%
student_productivity.iloc[-876]
# Out:
# student_id                19125
# age                          23
# gender                   Female
# study_hours_per_day        0.57
# sleep_hours                3.22
# phone_usage_hours          4.26
# social_media_hours         5.85
# youtube_hours              3.36
# gaming_hours               0.71
# breaks_per_day                5
# coffee_intake_mg            234
# exercise_minutes             62
# assignments_completed         1
# attendance_percentage     56.59
# stress_level                  9
# focus_score                  88
# final_grade               81.35
# productivity_score        25.95
# Name: 19124, dtype: object

# %%
student_productivity.loc[567, "attendance_percentage"]
# Out:
# np.float64(82.23)

# %%
student_productivity.loc[3, ["study_hours_per_day", "phone_usage_hours", "sleep_hours"]]
# Out:
# study_hours_per_day     3.19
# phone_usage_hours      10.06
# sleep_hours             4.58
# Name: 3, dtype: object

# %%
student_productivity.set_index("age")
# Out:
#      student_id  gender  study_hours_per_day  sleep_hours  phone_usage_hours  \
# age
# 23            1  Female                 4.35         3.63               3.38
# 20            2    Male                 6.14         6.58               5.48
# 29            3  Female                 4.98         3.26               4.83
# 27            4  Female                 3.19         4.58              10.06
# 24            5    Male                 7.67         6.21               3.02
# ..          ...     ...                  ...          ...                ...
# 26        19996  Female                 4.81         7.83               6.86
# 22        19997   Other                 0.83         4.49               6.76
# 25        19998    Male                 9.36         4.33               2.94
# 22        19999  Female                 0.74         4.44               3.15
# 19        20000  Female                 3.64         6.35               8.68
#
# ...

# %%
student_productivity.loc[(student_productivity.gender == "Female") & (student_productivity.coffee_intake_mg > 300)]
# Out:
#        student_id  age  gender  study_hours_per_day  sleep_hours  \
# 0               1   23  Female                 4.35         3.63
# 2               3   29  Female                 4.98         3.26
# 9              10   19  Female                 7.28         9.56
# 19             20   22  Female                 4.61         9.58
# 29             30   28  Female                 4.10         8.97
# ...           ...  ...     ...                  ...          ...
# 19982       19983   27  Female                 3.16         6.45
# 19984       19985   23  Female                 3.90         4.25
# 19991       19992   28  Female                 2.72         5.55
# 19995       19996   26  Female                 4.81         7.83
# 19998       19999   22  Female                 0.74         4.44
#
#        phone_usage_hours  social_media_hours  youtube_hours  gaming_hours  \
# 0                   3.38                2.73           1.83          5.26
# ...

# %%
student_productivity.loc[(student_productivity.sleep_hours >= 3.00) & (student_productivity.phone_usage_hours > 3.00)]
# Out:
#        student_id  age  gender  study_hours_per_day  sleep_hours  \
# 0               1   23  Female                 4.35         3.63
# 1               2   20    Male                 6.14         6.58
# 2               3   29  Female                 4.98         3.26
# 3               4   27  Female                 3.19         4.58
# 4               5   24    Male                 7.67         6.21
# ...           ...  ...     ...                  ...          ...
# 19994       19995   20    Male                 9.84         4.99
# 19995       19996   26  Female                 4.81         7.83
# 19996       19997   22   Other                 0.83         4.49
# 19998       19999   22  Female                 0.74         4.44
# 19999       20000   19  Female                 3.64         6.35
#
#        phone_usage_hours  social_media_hours  youtube_hours  gaming_hours  \
# 0                   3.38                2.73           1.83          5.26
# ...

# %%
student_productivity.loc[student_productivity.focus_score.isin([57, 49])]
# Out:
#        student_id  age  gender  study_hours_per_day  sleep_hours  \
# 0               1   23  Female                 4.35         3.63
# 1               2   20    Male                 6.14         6.58
# 54             55   20  Female                 2.08         3.04
# 105           106   25    Male                 6.85         4.12
# 127           128   23  Female                 4.12         9.36
# ...           ...  ...     ...                  ...          ...
# 19856       19857   27  Female                 6.20         9.56
# 19859       19860   17    Male                 9.33         4.67
# 19882       19883   26    Male                 4.09         3.09
# 19923       19924   23    Male                 3.27         6.94
# 19933       19934   17    Male                 4.65         4.16
#
#        phone_usage_hours  social_media_hours  youtube_hours  gaming_hours  \
# 0                   3.38                2.73           1.83          5.26
# ...

# %%
student_productivity["assignments_completed"] = 10
student_productivity
# Out:
#        student_id  age  gender  study_hours_per_day  sleep_hours  \
# 0               1   23  Female                 4.35         3.63
# 1               2   20    Male                 6.14         6.58
# 2               3   29  Female                 4.98         3.26
# 3               4   27  Female                 3.19         4.58
# 4               5   24    Male                 7.67         6.21
# ...           ...  ...     ...                  ...          ...
# 19995       19996   26  Female                 4.81         7.83
# 19996       19997   22   Other                 0.83         4.49
# 19997       19998   25    Male                 9.36         4.33
# 19998       19999   22  Female                 0.74         4.44
# 19999       20000   19  Female                 3.64         6.35
#
#        phone_usage_hours  social_media_hours  youtube_hours  gaming_hours  \
# 0                   3.38                2.73           1.83          5.26
# ...

# %%
student_productivity["exercise_minutes"] = range(len(student_productivity.exercise_minutes),0,-1)
student_productivity["exercise_minutes"]
# Out:
# 0        20000
# 1        19999
# 2        19998
# 3        19997
# 4        19996
#          ...
# 19995        5
# 19996        4
# 19997        3
# 19998        2
# 19999        1
# Name: exercise_minutes, Length: 20000, dtype: int64

# %%
query = """
SELECT gender, final_grade, productivity_score FROM my_table
ORDER BY gender asc
LIMIT 10;
"""
sql_my_table = pd.read_sql_query(query, con=engine)
print(sql_my_table)
# Out:
#    gender  final_grade  productivity_score
# 0  Female        81.87               33.78
# 1  Female        86.22               36.60
# 2  Female        71.77               19.87
# 3  Female        62.71               41.23
# 4  Female        52.22               53.81
# 5  Female        88.53               73.18
# 6  Female        73.23               59.99
# 7  Female        62.96               47.04
# 8  Female        84.31               32.60
# 9  Female        82.13               35.45

# %%
query = """
SELECT assignments_completed, attendance_percentage FROM my_table
ORDER BY final_grade asc
LIMIT 3 OFFSET 100;
"""
sql_my_table = pd.read_sql_query(query, con=engine)
print(sql_my_table)
# Out:
#    assignments_completed  attendance_percentage
# 0                     10                  50.29
# 1                     10                  50.55
# 2                     10                  53.27

# %%
query = """
SELECT DISTINCT age FROM my_table ORDER BY age asc;
"""
sql_my_table = pd.read_sql_query(query, con=engine)
print(sql_my_table)
# Out:
#     age
# 0    17
# 1    18
# 2    19
# 3    20
# 4    21
# 5    22
# 6    23
# 7    24
# 8    25
# 9    26
# 10   27
# 11   28
# 12   29
