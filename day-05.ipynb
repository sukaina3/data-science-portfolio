# %%
import pandas as pd

# %%
student_productivity = pd.read_csv(r"C:\Users\sukai\Downloads\archive (2).zip")
student_productivity.head()
# Out:
#    student_id  age gender academic_level  study_hours  self_study_hours  \
# 0           1   18  Other    High School         7.64              1.56
# 1           2   18  Other    High School         2.21              2.22
# 2           3   22   Male    High School         3.45              0.00
# 3           4   17  Other    High School         5.75              2.08
# 4           5   19  Other    High School         6.83              1.72
#
#    online_classes_hours  social_media_hours  gaming_hours  sleep_hours  ...  \
# 0                  2.20                3.05          2.19         6.52  ...
# 1                  2.10                1.65          2.55         5.97  ...
# 2                  0.29                1.34          2.08         8.39  ...
# 3                  3.01                2.27          2.20         6.31  ...
# 4                  3.33                2.65          0.70         8.01  ...
#
# ...

# %%
student_distraction = pd.read_csv(r"C:\Users\sukai\Downloads\archive (3).zip")
student_distraction.head()
# Out:
#    student_id  age  gender  study_hours_per_day  sleep_hours  \
# 0           1   23  Female                 4.35         3.63
# 1           2   20    Male                 6.14         6.58
# 2           3   29  Female                 4.98         3.26
# 3           4   27  Female                 3.19         4.58
# 4           5   24    Male                 7.67         6.21
#
#    phone_usage_hours  social_media_hours  youtube_hours  gaming_hours  \
# 0               3.38                2.73           1.83          5.26
# 1               5.48                1.51           3.13          1.73
# 2               4.83                3.63           0.18          4.71
# 3              10.06                3.95           5.75          2.52
# 4               3.02                1.59           5.46          5.65
#
#    breaks_per_day  coffee_intake_mg  exercise_minutes  assignments_completed  \
# 0               6               347               111                      2
# ...

# %%
#rename
renamed = student_productivity.rename(columns=({"academic_level":"school_level"}))
renamed.head()
# Out:
#    student_id  age gender school_level  study_hours  self_study_hours  \
# 0           1   18  Other  High School         7.64              1.56
# 1           2   18  Other  High School         2.21              2.22
# 2           3   22   Male  High School         3.45              0.00
# 3           4   17  Other  High School         5.75              2.08
# 4           5   19  Other  High School         6.83              1.72
#
#    online_classes_hours  social_media_hours  gaming_hours  sleep_hours  ...  \
# 0                  2.20                3.05          2.19         6.52  ...
# 1                  2.10                1.65          2.55         5.97  ...
# 2                  0.29                1.34          2.08         8.39  ...
# 3                  3.01                2.27          2.20         6.31  ...
# 4                  3.33                2.65          0.70         8.01  ...
#
#    exercise_minutes  caffeine_intake_mg  part_time_job  upcoming_deadline  \
# ...

# %%
#rename rows and columns
rename = student_distraction.rename_axis("ID", axis = "rows")
rename.head()
# Out:
#     student_id  age  gender  study_hours_per_day  sleep_hours  \
# ID
# 0            1   23  Female                 4.35         3.63
# 1            2   20    Male                 6.14         6.58
# 2            3   29  Female                 4.98         3.26
# 3            4   27  Female                 3.19         4.58
# 4            5   24    Male                 7.67         6.21
#
#     phone_usage_hours  social_media_hours  youtube_hours  gaming_hours  \
# ID
# 0                3.38                2.73           1.83          5.26
# 1                5.48                1.51           3.13          1.73
# 2                4.83                3.63           0.18          4.71
# 3               10.06                3.95           5.75          2.52
# 4                3.02                1.59           5.46          5.65
#
#     breaks_per_day  coffee_intake_mg  exercise_minutes  assignments_completed  \
# ID
# ...

# %%
#combining
#concat()
combined_data = pd.concat([student_productivity, student_distraction])
combined_data.head()
# Out:
#    student_id  age gender academic_level  study_hours  self_study_hours  \
# 0           1   18  Other    High School         7.64              1.56
# 1           2   18  Other    High School         2.21              2.22
# 2           3   22   Male    High School         3.45              0.00
# 3           4   17  Other    High School         5.75              2.08
# 4           5   19  Other    High School         6.83              1.72
#
#    online_classes_hours  social_media_hours  gaming_hours  sleep_hours  ...  \
# 0                  2.20                3.05          2.19         6.52  ...
# 1                  2.10                1.65          2.55         5.97  ...
# 2                  0.29                1.34          2.08         8.39  ...
# 3                  3.01                2.27          2.20         6.31  ...
# 4                  3.33                2.65          0.70         8.01  ...
#
#    study_hours_per_day  phone_usage_hours  youtube_hours  breaks_per_day  \
# ...

# %%
#join
left = student_productivity
right = student_distraction
left.join(right, lsuffix = "_p", rsuffix = "_d")
# Out:
#       student_id_p  age_p gender_p academic_level  study_hours  \
# 0                1     18    Other    High School         7.64
# 1                2     18    Other    High School         2.21
# 2                3     22     Male    High School         3.45
# 3                4     17    Other    High School         5.75
# 4                5     19    Other    High School         6.83
# ...            ...    ...      ...            ...          ...
# 4995          4996     20    Other  Undergraduate         3.93
# 4996          4997     24     Male    High School         4.00
# 4997          4998     22     Male  Undergraduate         5.63
# 4998          4999     17     Male  Undergraduate         3.58
# 4999          5000     22    Other  Undergraduate         5.60
#
#       self_study_hours  online_classes_hours  social_media_hours_p  \
# 0                 1.56                  2.20                  3.05
# 1                 2.22                  2.10                  1.65
# ...
